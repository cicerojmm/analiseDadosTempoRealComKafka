# %%
from kafka import KafkaConsumer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import json
from IPython.display import clear_output

# %%
#configuração do kafka
brokers = ['localhost:9092']
topic = 'devfest-cerrado'

consumer = KafkaConsumer(topic, group_id = 'group1', bootstrap_servers = brokers)

# %%
#geração da nuvem de palavras em tempo real
frases = ''
for messagem in consumer:
    texto = json.loads(messagem.value.decode('utf-8'))
    frases = frases + texto['tweet']
    clear_output()
    wordcloud = WordCloud(max_font_size=100, width = 1520, height = 535).generate(frases)
    plt.figure(figsize=(16,9))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-d0efd145c6a0> in <module>
#       1 #geração da nuvem de palavras em tempo real
#       2 frases = ''
# ----> 3 for messagem in consumer:
#       4     texto = json.loads(messagem.value.decode('utf-8'))
#       5     frases = frases + texto['tweet']
#
# /usr/local/lib/python3.5/dist-packages/kafka/consumer/group.py in __next__(self)
#    1073         self._set_consumer_timeout()
#    1074         try:
# -> 1075             return next(self._iterator)
#    1076         except StopIteration:
#    1077             self._iterator = None
#
# /usr/local/lib/python3.5/dist-packages/kafka/consumer/group.py in _message_generator(self)
#    1011             if not self._fetcher.in_flight_fetches():
#    1012                 poll_ms = 0
# -> 1013             self._client.poll(timeout_ms=poll_ms)
#    1014
#    1015             # We need to make sure we at least keep up with scheduled tasks,
#
# /usr/local/lib/python3.5/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future, delayed_tasks)
#     552                 timeout = max(0, timeout / 1000.0)  # avoid negative timeouts
#     553
# --> 554             responses.extend(self._poll(timeout))
#     555
#     556             # If all we had was a timeout (future is None) - only do one poll
#
# /usr/local/lib/python3.5/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     566
#     567         start_select = time.time()
# --> 568         ready = self._selector.select(timeout)
#     569         end_select = time.time()
#     570         if self._sensors:
#
# /usr/lib/python3.5/selectors.py in select(self, timeout)
#     439             ready = []
#     440             try:
# --> 441                 fd_event_list = self._epoll.poll(timeout, max_ev)
#     442             except InterruptedError:
#     443                 return ready
#
# KeyboardInterrupt:
